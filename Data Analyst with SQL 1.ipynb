# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandasql as ps
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: six>=1.5 in c:\users\mypc\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# ...

# %%
import pandas as pd
import pandasql as ps

# %%
ti=pd.read_csv('C://Users//Mypc//Desktop//Unacademy ML//SQL-for-Data-Analytics-main//titanic.csv')

# %%
ti
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ti.shape
# Out:
# (891, 12)

# %%
ti.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
ti.duplicated().sum()
# Out:
# 0

# %%
# select all the data
ps.sqldf("""
    SELECT 
    df.* FROM ti AS df
""")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# select Limit to get top 5

ps.sqldf("""
    SELECT 
    df.* FROM ti AS df
    LIMIT 5
""")
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %%
# Taking only PassengerID and the name frpm dataset
ps.sqldf("""
    SELECT
    df.PassengerId,
    df.Name           
    FROM ti AS df
    LIMIT 5
""")
# Out:
#    PassengerId                                               Name
# 0            1                            Braund, Mr. Owen Harris
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3                             Heikkinen, Miss. Laina
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5                           Allen, Mr. William Henry

# %%
# RENAME THE TWO CHOSEN COLUMN
ps.sqldf("""
SELECT 
    df.PassengerId AS ID_OF_Passenger,
    df.Name AS Name_Of_Passenger
    FROM ti AS df
    LIMIT 5
""")
# Out:
#    ID_OF_Passenger                                  Name_Of_Passenger
# 0                1                            Braund, Mr. Owen Harris
# 1                2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                3                             Heikkinen, Miss. Laina
# 3                4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                5                           Allen, Mr. William Henry

# %%
# Sele t all the passenger whoes age is below 1 year
ps.sqldf("""
    SELECT 
    df.*
    FROM ti AS df
    WHERE df.age < 1
""")
# Out:
#    PassengerId  Survived  Pclass                             Name     Sex  \
# 0           79         1       2    Caldwell, Master. Alden Gates    male
# 1          306         1       1   Allison, Master. Hudson Trevor    male
# 2          470         1       3    Baclini, Miss. Helene Barbara  female
# 3          645         1       3           Baclini, Miss. Eugenie  female
# 4          756         1       2        Hamalainen, Master. Viljo    male
# 5          804         1       3  Thomas, Master. Assad Alexander    male
# 6          832         1       2  Richards, Master. George Sibley    male
#
#     Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 0  0.83      0      2  248738   29.0000     None        S
# 1  0.92      1      2  113781  151.5500  C22 C26        S
# 2  0.75      2      1    2666   19.2583     None        C
# 3  0.75      2      1    2666   19.2583     None        C
# 4  0.67      1      1  250649   14.5000     None        S
# ...

# %%
# Giving an alias name to the dataset and using it in "SELECT" statement too

ps.sqldf("""

SELECT
    df.*
    FROM ti as df
    
""")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# You can check for missing value by using "ISNULL"

ps.sqldf("""
SELECT 
    df.*
    FROM ti as df
    WHERE df.age NOT NULL
""")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Example for "BETWEEN" keyword

ps.sqldf("""
SELECT 
df.*
FROM ti AS df
WHERE df.age BETWEEN 5 AND 10
""")
# Out:
#     PassengerId  Survived  Pclass  \
# 0            25         0       3
# 1            51         0       3
# 2            59         1       2
# 3           148         0       3
# 4           166         1       3
# 5           183         0       3
# 6           234         1       3
# 7           238         1       2
# 8           279         0       3
# 9           420         0       3
# 10          449         1       3
# 11          481         0       3
# 12          490         1       3
# 13          536         1       2
# 14          542         0       3
# 15          550         1       2
# 16          635         0       3
# 17          721         1       2
# 18          752         1       3
# 19          778         1       3
# 20          788         0       3
# 21          814         0       3
# 22          820         0       3
# 23          853         0       3
#
#                                                Name     Sex   Age  SibSp  \
# ...

# %%
# Selecting everything from the Dataset for passenger whoes age is beloww 1 year and who are females

ps.sqldf("""
    SELECT
    df.*
    FROM ti AS df
    WHERE df.age<1
    AND df.Sex="female"
""")
# Out:
#    PassengerId  Survived  Pclass                           Name     Sex   Age  \
# 0          470         1       3  Baclini, Miss. Helene Barbara  female  0.75
# 1          645         1       3         Baclini, Miss. Eugenie  female  0.75
#
#    SibSp  Parch Ticket     Fare Cabin Embarked
# 0      2      1   2666  19.2583  None        C
# 1      2      1   2666  19.2583  None        C

# %%
# Selecting everything from the Dataset for passenger whoes age is beloww 1 year and who are females or age is above 70 year and Pclass is 1

ps.sqldf("""
    SELECT df.*
    FROM ti AS df
    WHERE (df.Age<1 AND df.Sex="female")
    OR (df.Age>70 AND df.Pclass=1)
""")
# Out:
#    PassengerId  Survived  Pclass                                  Name  \
# 0           97         0       1             Goldschmidt, Mr. George B
# 1          470         1       3         Baclini, Miss. Helene Barbara
# 2          494         0       1               Artagaveytia, Mr. Ramon
# 3          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 4          645         1       3                Baclini, Miss. Eugenie
#
#       Sex    Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 0    male  71.00      0      0  PC 17754  34.6542    A5        C
# 1  female   0.75      2      1      2666  19.2583  None        C
# 2    male  71.00      0      0  PC 17609  49.5042  None        C
# 3    male  80.00      0      0     27042  30.0000   A23        S
# 4  female   0.75      2      1      2666  19.2583  None        C

# %%
# selecting everthing from the dataset for passenger where cabin is one og A5,A6, A7

ps.sqldf("""
SELECT df.*
FROM ti AS df
WHERE df.Cabin IN ('A5','A6','A7')
""")
# Out:
#    PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0           24         1       1  Sloper, Mr. William Thompson  male  28.0
# 1           97         0       1     Goldschmidt, Mr. George B  male  71.0
# 2          175         0       1       Smith, Mr. James Clinch  male  56.0
#
#    SibSp  Parch    Ticket     Fare Cabin Embarked
# 0      0      0    113788  35.5000    A6        S
# 1      0      0  PC 17754  34.6542    A5        C
# 2      0      0     17764  30.6958    A7        C

# %%
# Selecting everything from the datasets for passengers where Age is one of 65,70,71

ps.sqldf("""
SELECT df.*
FROM ti AS df
WHERE df.Age IN (65,70,71)
""")
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0           55         0       1  Ostby, Mr. Engelhart Cornelius  male  65.0
# 1           97         0       1       Goldschmidt, Mr. George B  male  71.0
# 2          281         0       3                Duane, Mr. Frank  male  65.0
# 3          457         0       1       Millet, Mr. Francis Davis  male  65.0
# 4          494         0       1         Artagaveytia, Mr. Ramon  male  71.0
# 5          673         0       2     Mitchell, Mr. Henry Michael  male  70.0
# 6          746         0       1    Crosby, Capt. Edward Gifford  male  70.0
#
#    SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      0      1      113509  61.9792   B30        C
# 1      0      0    PC 17754  34.6542    A5        C
# 2      0      0      336439   7.7500  None        Q
# 3      0      0       13509  26.5500   E38        S
# 4      0      0    PC 17609  49.5042  None        C
# ...

# %%
# selecting everything from the datasets for passenger where name contains 'Mrs.'

ps.sqldf("""
SELECT df.*
FROM ti AS df
WHERE df.Name LIKE "%MRS.%"
LIMIT 5
""")
# Out:
#    PassengerId  Survived  Pclass  \
# 0            2         1       1
# 1            4         1       1
# 2            9         1       3
# 3           10         1       2
# 4           16         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 3                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 4                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 0      0  PC 17599  71.2833   C85        C
# 1      0    113803  53.1000  C123        S
# 2      2    347742  11.1333  None        S
# 3      0    237736  30.0708  None        C
# 4      0    248706  16.0000  None        S

# %%
# Adding a column for Square,Log,Root etc of
ps.sqldf("""
SELECT 
df.Age,
df.Age * df.Age AS age_sq,
df.Age + 1 AS df.plus
FROM ti AS df
LIMIT 5

""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1265                 if not evt_handled:
# -> 1266                     self.dialect.do_execute_no_params(
#    1267                         cursor, statement, context
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute_no_params(self, cursor, statement, context)
#     595     def do_execute_no_params(self, cursor, statement, context=None):
# --> 596         cursor.execute(statement)
#     597
#
# OperationalError: near ".": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
# concatenate two string
ps.sqldf("""
SELECT 
df.Sex,
df.Ticket,
df.Sex || df.Ticket AS Sex_plus_ticket
FROM ti AS df
LIMIT 5
""")
# Out:
#       Sex            Ticket         Sex_plus_ticket
# 0    male         A/5 21171           maleA/5 21171
# 1  female          PC 17599          femalePC 17599
# 2  female  STON/O2. 3101282  femaleSTON/O2. 3101282
# 3  female            113803            female113803
# 4    male            373450              male373450

# %%
# Using CASE WHEN to create buckets for age

ps.sqldf("""
SELECT 
df.Name,
df.PassengerID,
df.Age,
CASE 
WHEN df.Age IS NULL THEN '0. Missing'
WHEN df.Age < 18 THEN '1. 1-17'
WHEN df.AGE < 60 THEN '2. 18-60'
ELSE '3.60+' END AS age_bucket
FROM ti AS df
LIMIT 50

""")
# Out:
#                                                  Name  PassengerId   Age  \
# 0                             Braund, Mr. Owen Harris            1  22.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...            2  38.0
# 2                              Heikkinen, Miss. Laina            3  26.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)            4  35.0
# 4                            Allen, Mr. William Henry            5  35.0
# 5                                    Moran, Mr. James            6   NaN
# 6                             McCarthy, Mr. Timothy J            7  54.0
# 7                      Palsson, Master. Gosta Leonard            8   2.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9  27.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)           10  14.0
# 10                    Sandstrom, Miss. Marguerite Rut           11   4.0
# 11                           Bonnell, Miss. Elizabeth           12  58.0
# ...

# %%
# Using SUBSTR() to take out a substring

ps.sqldf("""
SELECT 
df.Name,
SUBSTR(df.Name,2,4) AS out
FROM ti AS df
LIMIT 5
""")
# Out:
#                                                 Name   out
# 0                            Braund, Mr. Owen Harris  raun
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  umin
# 2                             Heikkinen, Miss. Laina  eikk
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  utre
# 4                           Allen, Mr. William Henry  llen

# %%
# Lower() and Upper()
ps.sqldf("""
Select
df.Name,
LOWER(df.Name) AS lcase_name,
UPPER(df.Name) AS ucase_name
FROM ti AS df
LIMIT 5
""")
# Out:
#                                                 Name  \
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
#
#                                           lcase_name  \
# 0                            braund, mr. owen harris
# 1  cumings, mrs. john bradley (florence briggs th...
# 2                             heikkinen, miss. laina
# 3       futrelle, mrs. jacques heath (lily may peel)
# 4                           allen, mr. william henry
#
#                                           ucase_name
# 0                            BRAUND, MR. OWEN HARRIS
# 1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                             HEIKKINEN, MISS. LAINA
# 3       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                           ALLEN, MR. WILLIAM HENRY

# %%
# Selecting all distinct vbalue of "Embarked" column
ps.sqldf("""
SELECT
DISTINCT df.Embarked
FROM ti AS df
""")
# Out:
#   Embarked
# 0        S
# 1        C
# 2        Q
# 3     None
